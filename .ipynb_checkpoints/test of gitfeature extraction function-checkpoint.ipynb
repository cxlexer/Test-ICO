# %%
import json
import numpy as np
import requests 
import pandas as pd
from bs4 import BeautifulSoup as bs
from operator import itemgetter 
import time

# %%
RAW_DATA_FILEPATH = '/users/eric/PycharmProjects/testico/api_data.json'
URL_FILEPATH = '/users/eric/PycharmProjects/testico/ico_urls.txt'
TOKEN_FILE = '/users/eric/PycharmProjects/testico/token.csv'
FULLDATA_FILE = '/users/eric/PycharmProjects/testico/fulldata.csv'
NUMERICAL_DATA_FILE = '/users/eric/PycharmProjects/testico/full_num.csv'
TEXT_DATA_FILE = '/users/eric/PycharmProjects/testico/textfeature_dataframe.csv'
URL_COPY_FILEPATH = '/users/eric/PycharmProjects/testico/ico_urls copy.txt'

# %%
def repolink_extract(url):
    try:
        html = requests.get(url)
    except Exception as e:
        print(e)
        print(url)
        return None
    htmltxt = bs(html.text, 'html.parser')
    
    
    repohtml = htmltxt.find_all('a', class_="d-inline-block", 
                                itemprop="name codeRepository")

    partial_repolink_list = []
    for item in repohtml:
        link = item.attrs['href']
        partial_repolink_list.append(link)
    return partial_repolink_list
    

    

def nextpage_extract(url):
    try:
        html = requests.get(url)
    except Exception as e:
        print(e)
        print(url)
        return None
    htmltxt = bs(html.text, 'html.parser')

    nextpage = htmltxt.find_all('a', 
                    class_="next_page",
                    rel="next")
    if len(nextpage) != 0:
        a = 'https://github.com'
        next_ = nextpage[0].attrs['href']
        nextlink = '{}{}'.format(a, next_)
        return nextlink
    else:
        return None


def repolink_extract_paginator(current_url):
    output = repolink_extract(current_url)
    next_url = nextpage_extract(current_url)
    while next_url is not None:
        current_url = next_url
        output_temp = repolink_extract(current_url)
        output.append(output_temp)
        next_url = nextpage_extract(current_url)
        time.sleep(1)
    repolink_list = []
    def reemoveNestings(l):
        for i in l:
            if type(i) == list:
                reemoveNestings(i)
            else:
                repolink_list.append(i)
    reemoveNestings(output)
    
    return repolink_list

def gitfeature_extract(partial_repolink):
    gitfeature_empty = {
            'watchers':0,
            'stars': 0,
            'forks':0, 
            'commits':0,
            'branches':0}
    a = 'https://github.com'
    full_repolink = '{}{}'.format(a, partial_repolink)
    try:
        githtml = requests.get(full_repolink)
    except Exception as e:
        print(e)
        print(partial_repolink)
        gitfeature = {
            'watchers':0,
            'stars': 0,
            'forks':0, 
            'commits':0,
            'branches':0}
        return gitfeature
    githtmltxt = bs(githtml.text, 'html.parser')
    otherfeature_html = githtmltxt.find_all(
       'span', class_="num text-emphasized")
    if len(otherfeature_html) == 0:
        
        return gitfeature_empty
    else:
        
        watch_html = githtmltxt.find_all(
            'a', 
            class_="social-count",
            href= '{}{}'.format(partial_repolink,'/watchers')
        )
        if len(watch_html) == 0:
            return gitfeature_empty
        else:

            watch = watch_html[0].text.strip().replace(',', '')
            stars_html = githtmltxt.find_all(
                'a',
                class_="social-count",
                href= '{}{}'.format(partial_repolink,'/stargazers')
            )
            stars = stars_html[0].text.strip().replace(',', '')
            forks_html = githtmltxt.find_all(
                'a',
                href= '{}{}'.format(partial_repolink,'/network/members'),
                class_="social-count"
            )

            forks = forks_html[0].text.strip().replace(',', '')

            otherfeature_html = githtmltxt.find_all(
               'span', class_="num text-emphasized")
            commits = otherfeature_html[0].text.strip().replace(',', '')
            branches = otherfeature_html[1].text.strip().replace(',', '')
            releases = otherfeature_html[2].text.strip().replace(',', '')
            gitfeature = {
                'watchers':watch,
                'stars': stars,
                'forks':forks, 
                'commits':commits,
                'branches':branches}
            return gitfeature
    


            

def repofeature_extract_paginator(current_url):
    output = repolink_extract(current_url)
    next_url = nextpage_extract(current_url)
    while next_url is not None:
        current_url = next_url
        output_temp = repolink_extract(current_url)
        output.append(output_temp)
        next_url = nextpage_extract(current_url)
        time.sleep(1)
    repolink_list = []
    def reemoveNestings(l):
        for i in l:
            if type(i) == list:
                reemoveNestings(i)
            else:
                repolink_list.append(i)
    reemoveNestings(output)
    d_list = []
    feature_sum = {}
    for partial_repolink in repolink_list:
        feature_dic = gitfeature_extract(partial_repolink)
        d_list.append(feature_dic)
    for d in d_list:
        for k in d.keys():
            feature_sum[k] = feature_sum.get(k, 0) + int((d[k]))
    return feature_sum

def gitfeature_html(github_account_html):
    if github_account_html is None:
        gitfeature = {
            'watchers':0,
            'stars': 0,
            'forks':0, 
            'commits':0,
            'branches':0}
        return gitfeature
    else:
        try:
            html = requests.get(github_account_html)
        except Exception as e:
            print(e)
            print(url)
            gitfeature ={
            'watchers':0,
            'stars': 0,
            'forks':0, 
            'commits':0,
            'branches':0}
            return gitfeature
        htmltxt = bs(html.text, 'html.parser')
        repohtml = htmltxt.find_all('a',class_="d-inline-block", 
                                    itemprop="name codeRepository")
        if len(repohtml) == 0:
            output = gitfeature_extract(github_account_html.replace('https://github.com', ''))
            return output


        else:
            output = repofeature_extract_paginator(github_account_html)
            return output
        
def get_webpage_link(html_body):

    html = html_body.find_all("div", class_="col-xs-6 col-md-6")
    if len(html) == 0:
        return None
    html2 = html[1]
    html3 = html2.contents
    website = [ii for ii in html3 if not ii == '\n'][0]
    weblink = website.get('href')
    return weblink


def get_github_link(html_body):

    html2 = html_body.find_all("div", class_="col-xs-6 col-md-9")
    if len(html2) == 0:
        return None
    icon = html2[0]
    icon1 = icon.contents
    link = [item for item in icon1 if not item == '\n']
    linktxt = []
    for xx in link:
        bb = xx.get('href')
        linktxt.append(bb)

    for xx in linktxt:
        if 'github' in xx:
            return xx

    return None

# %%
with open(URL_FILEPATH, 'r') as f:
    urls = f.readlines()

urls = [url.strip('\n') for url in urls]
results = []
for url in urls:
    html = requests.get(url)
    htmltxt = bs(html.text, 'html.parser')
    htmlbody = htmltxt.body
    heads = htmlbody.find_all("div", class_="col-xs-6 col-md-3")[2:]
    heads = [head.text.strip().split('\n')[0] for head in heads]
    datas = htmlbody.find_all("div", class_="col-xs-6 col-md-9")[2:]
    datas = [data.text.strip().split('\n')[0] for data in datas]
    ico_results = list(zip(heads, datas))


    github_link = get_github_link(htmlbody)
    website_link = get_webpage_link(htmlbody)
    ico_results.append(('Github URL', github_link))
    ico_results.append(('Official Website', website_link))
    ß
    
    git_feature = gitfeature_html(github_link)
    git_feature_list = []
    for key, value in git_feature.items():
        temp=(key, value)
        git_feature_list.append(temp)
        
    joinedlist = ico_results + git_feature_list
    results.append(joinedlist) 
    


final_results = []
for result in results:
    dict_result = {key: value for (key, value) in result}
    final_results.append(dict_result)

for idx, url in enumerate(urls):
    name = url.split('/')[-1]
    final_results[idx]['name'] = name
    final_results[idx]['url'] = url

df = pd.DataFrame(final_results)
# df.to_csv('token_with_github_feature.csv')
# Out:
# HTTPSConnectionPool(host='github.comhttps', port=443): Max retries exceeded with url: //www.github.com/expa%20%20nse-org (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x110524898>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# https://www.github.com/expa  nse-org
# HTTPSConnectionPool(host='github.comhttp', port=443): Max retries exceeded with url: //www.github.com/cryptonetix (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x114a8db00>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# http://www.github.com/cryptonetix
# HTTPSConnectionPool(host='github.comhttps', port=443): Max retries exceeded with url: //gist.github.com/Credits-com (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x115625d68>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# https://gist.github.com/Credits-com
# HTTPSConnectionPool(host='github.comhttp', port=443): Max retries exceeded with url: //github.com/etherlegendsorg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x115115dd8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# http://github.com/etherlegendsorg
# HTTPSConnectionPool(host='github.comhttps', port=443): Max retries exceeded with url: //gist.github.com/patron-ico/bfe89d6404e870aa68b0953ae9beea7c (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x114f30048>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# https://gist.github.com/patron-ico/bfe89d6404e870aa68b0953ae9beea7c

# %%
urldf
# Out:
# 'https://icowatchlist.com/ico/assistivereality'

# %%
df
# Out:
#                 Accepted Currencies Coin Symbol         Country Funding Goal  \
# 0                               NaN         REP         Unknown          NaN
# 1                               NaN         REP         Unknown          NaN
# 2                               NaN         LSK         Germany          NaN
# 3                               NaN         LSK         Germany          NaN
# 4                               NaN         DGD       Singapore          NaN
# 5                               NaN         DGD       Singapore          NaN
# 6                               NaN       WAVES         Unknown          NaN
# 7                               NaN       WAVES         Unknown          NaN
# 8                               NaN       STRAT  United Kingdom          NaN
# 9                               NaN       STRAT  United Kingdom          NaN
# 10                              NaN         XTO   United States          NaN
# 11                              NaN         XTO   United States          NaN
# 12                              NaN       INCNT       Australia          NaN
# 13                              NaN       INCNT       Australia          NaN
# 14                              NaN         NEO           China          NaN
# 15                              NaN         NEO           China          NaN
# 16                              NaN    BLOCKPAY         Denmark          NaN
# 17                              NaN    BLOCKPAY         Denmark          NaN
# 18                              NaN         1ST   United States          NaN
# 19                              NaN         1ST   United States          NaN
# 20                              NaN         ICN         Unknown          NaN
# 21                              NaN         ICN         Unknown          NaN
# 22                              NaN         LKK     Switzerland          NaN
# 23                              NaN         LKK     Switzerland          NaN
# 24                              NaN         AMP          Israel          NaN
# 25                              NaN         AMP          Israel          NaN
# 26                              NaN       SNGLS   United States          NaN
# 27                              NaN       SNGLS   United States          NaN
# 28                              NaN         NXC         Unknown          NaN
# 29                              NaN         NXC         Unknown          NaN
# ...                             ...         ...             ...          ...
# 1456                            ETH         GZB  United Kingdom          NaN
# 1457                            ETH         GZB  United Kingdom          NaN
# 1458             BTC, ETH, USD, EUR        MOBU    South Africa          NaN
# 1459             BTC, ETH, USD, EUR        MOBU    South Africa          NaN
# 1460                            ETH       RECSH         Germany          NaN
# 1461                            ETH       RECSH         Germany          NaN
# 1462                       ETH, BTC         HUS         Estonia          NaN
# 1463                       ETH, BTC         HUS         Estonia          NaN
# 1464                            ETH        KEYO       Singapore          NaN
# 1465                            ETH        KEYO       Singapore          NaN
# 1466                            ETH        BTMG          Poland  $15,000,000
# 1467                            ETH        BTMG          Poland  $15,000,000
# 1468                       BTC, ETH         BUY   United States          NaN
# 1469                       BTC, ETH         BUY   United States          NaN
# 1470                            ETH        PANX         Austria          NaN
# 1471                            ETH        PANX         Austria          NaN
# 1472                       BTC, ETH        LYNK     Netherlands          NaN
# 1473                       BTC, ETH        LYNK     Netherlands          NaN
# 1474  BTC, ETH, BCH, LTC, DASH, ETC          RF          Belize          NaN
# 1475  BTC, ETH, BCH, LTC, DASH, ETC          RF          Belize          NaN
# 1476                  BTC, ETH, LTC         BCV       Australia          NaN
# 1477                  BTC, ETH, LTC         BCV       Australia          NaN
# 1478                  BTC, ETH, XLM         PRY     Switzerland          NaN
# 1479                  BTC, ETH, XLM         PRY     Switzerland          NaN
# 1480             BTC, ETH, USD, XLM         WVR           Malta          NaN
# 1481             BTC, ETH, USD, XLM         WVR           Malta          NaN
# 1482             BTC, ETH, BCH, LTC        VANM         Germany          NaN
# 1483             BTC, ETH, BCH, LTC        VANM         Germany          NaN
# 1484                            ETH        NACL   United States          NaN
# 1485                            ETH        NACL   United States          NaN
#
#      Funds in Escrow?                                         Github URL  \
# 0                  No                    https://github.com/AugurProject
# 1                  No                    https://github.com/AugurProject
# 2                  No                          https://github.com/LiskHQ
# 3                  No                          https://github.com/LiskHQ
# 4                  No                     https://github.com/digixglobal
# 5                  No                     https://github.com/digixglobal
# 6                  No                  https://github.com/WAVESPLATFORM/
# 7                  No                  https://github.com/WAVESPLATFORM/
# 8                  No                                               None
# 9                  No                                               None
# 10                 No                                               None
# 11                 No                                               None
# 12                 No                                               None
# 13                 No                                               None
# 14                 No                                               None
# 15                 No                                               None
# 16                 No                                               None
# 17                 No                                               None
# 18                 No                    https://github.com/firstbloodio
# 19                 No                    https://github.com/firstbloodio
# 20                 No                                               None
# 21                 No                                               None
# 22                 No                      https://github.com/LykkeCity/
# 23                 No                      https://github.com/LykkeCity/
# 24                 No                         https://github.com/synereo
# 25                 No                         https://github.com/synereo
# 26                 No  https://github.com/ConsenSys/singulardtv-contr...
# 27                 No  https://github.com/ConsenSys/singulardtv-contr...
# 28                 No                                               None
# 29                 No                                               None
# ...               ...                                                ...
# 1456               No                           https://github.com/Gigzi
# 1457               No                           https://github.com/Gigzi
# 1458               No                                               None
# 1459               No                                               None
# 1460               No                                               None
# 1461               No                                               None
# 1462               No                        https://github.com/hussy-io
# 1463               No                        https://github.com/hussy-io
# 1464              Yes                                               None
# 1465              Yes                                               None
# 1466               No                     https://github.com/bitcademyfb
# 1467               No                     https://github.com/bitcademyfb
# 1468              Yes                      https://github.com/Buying-com
# 1469              Yes                      https://github.com/Buying-com
# 1470               No                                               None
# 1471               No                                               None
# 1472               No                     https://github.com/LynkedWorld
# 1473               No                     https://github.com/LynkedWorld
# 1474               No                                               None
# 1475               No                                               None
# 1476               No                                               None
# 1477               No                                               None
# 1478               No                                               None
# 1479               No                                               None
# 1480               No                                               None
# 1481               No                                               None
# 1482               No                    https://github.com/VANMofficial
# 1483               No                    https://github.com/VANMofficial
# 1484               No                                               None
# 1485               No                                               None
#
#      Have Prototype? Initial Token Price  \
# 0                NaN             $0.5800
# 1                NaN             $0.5800
# 2                NaN             $0.0747
# 3                NaN             $0.0747
# 4                NaN             $3.2400
# 5                NaN             $3.2400
# 6                NaN             $0.1880
# 7                NaN             $0.1880
# 8                NaN             $0.0073
# 9                NaN             $0.0073
# 10               NaN             $0.0100
# 11               NaN             $0.0100
# 12               NaN             $0.0470
# 13               NaN             $0.0470
# 14               NaN             $0.1590
# 15               NaN             $0.1590
# 16               NaN             $0.1240
# 17               NaN             $0.1240
# 18               NaN             $0.0692
# 19               NaN             $0.0692
# 20               NaN             $0.1200
# 21               NaN             $0.1200
# 22               NaN             $0.0500
# 23               NaN             $0.0500
# 24               NaN             $0.1597
# 25               NaN             $0.1597
# 26               NaN             $0.0150
# 27               NaN             $0.0150
# 28               NaN             $0.0100
# 29               NaN             $0.0100
# ...              ...                 ...
# 1456             NaN             $0.6000
# 1457             NaN             $0.6000
# 1458             NaN             $0.0000
# 1459             NaN             $0.0000
# 1460             NaN             $0.0000
# 1461             NaN             $0.0000
# 1462             NaN             $0.3600
# 1463             NaN             $0.3600
# 1464             Yes             $0.0500
# 1465             Yes             $0.0500
# 1466             NaN             $0.0380
# 1467             NaN             $0.0380
# 1468             NaN             $0.0700
# 1469             NaN             $0.0700
# 1470             NaN             $0.0310
# 1471             NaN             $0.0310
# 1472             Yes             $0.3500
# 1473             Yes             $0.3500
# 1474             Yes             $0.2000
# 1475             Yes             $0.2000
# 1476             Yes             $0.3700
# 1477             Yes             $0.3700
# 1478             NaN             $0.1000
# 1479             NaN             $0.1000
# 1480             Yes             $0.1000
# 1481             Yes             $0.1000
# 1482             NaN             $0.0880
# 1483             NaN             $0.0880
# 1484             Yes             $1.0000
# 1485             Yes             $1.0000
#
#                                        Official Website       Platform  ...  \
# 0                                https://www.augur.net/       Ethereum  ...
# 1                                https://www.augur.net/       Ethereum  ...
# 2                                      https://lisk.io/  Not Available  ...
# 3                                      https://lisk.io/  Not Available  ...
# 4                               https://www.dgx.io/dgd/       Ethereum  ...
# 5                               https://www.dgx.io/dgd/       Ethereum  ...
# 6                            https://wavesplatform.com/          Waves  ...
# 7                            https://wavesplatform.com/          Waves  ...
# 8                          https://stratisplatform.com/        Stratis  ...
# 9                          https://stratisplatform.com/        Stratis  ...
# 10                                  http://tao.network/  Not Available  ...
# 11                                  http://tao.network/  Not Available  ...
# 12                           http://incent.bitscan.com/          Waves  ...
# 13                           http://incent.bitscan.com/          Waves  ...
# 14                                     https://neo.org/            NEO  ...
# 15                                     https://neo.org/            NEO  ...
# 16                                 https://blockpay.ch/   Bitcoin Fork  ...
# 17                                 https://blockpay.ch/   Bitcoin Fork  ...
# 18                               https://firstblood.io/       Ethereum  ...
# 19                               https://firstblood.io/       Ethereum  ...
# 20                             https://www.iconomi.net/       Ethereum  ...
# 21                             https://www.iconomi.net/       Ethereum  ...
# 22                               https://www.lykke.com/     Blockchain  ...
# 23                               https://www.lykke.com/     Blockchain  ...
# 24                             https://www.synereo.com/  Not Available  ...
# 25                             https://www.synereo.com/  Not Available  ...
# 26                             https://singulardtv.com/       Ethereum  ...
# 27                             https://singulardtv.com/       Ethereum  ...
# 28                          http://beyond-the-void.net/       Ethereum  ...
# 29                          http://beyond-the-void.net/       Ethereum  ...
# ...                                                 ...            ...  ...
# 1456                                  https://gigzi.com       Ethereum  ...
# 1457                                  https://gigzi.com       Ethereum  ...
# 1458                               https://www.mobu.io/       Ethereum  ...
# 1459                               https://www.mobu.io/       Ethereum  ...
# 1460                                 http://reuse.cash/     Blockchain  ...
# 1461                                 http://reuse.cash/     Blockchain  ...
# 1462                                  https://hussy.io/       Ethereum  ...
# 1463                                  https://hussy.io/       Ethereum  ...
# 1464                          https://www.keypascoid.io       Ethereum  ...
# 1465                          https://www.keypascoid.io       Ethereum  ...
# 1466                              https://bitcademy.io/       Ethereum  ...
# 1467                              https://bitcademy.io/       Ethereum  ...
# 1468                                https://buying.com/       Ethereum  ...
# 1469                                https://buying.com/       Ethereum  ...
# 1470                           https://pantercon.com/en       Ethereum  ...
# 1471                           https://pantercon.com/en       Ethereum  ...
# 1472                    https://tokensale.lynked.world/       Ethereum  ...
# 1473                    https://tokensale.lynked.world/       Ethereum  ...
# 1474  https://raidofinance.com/?utm_source=icowatchlist       Ethereum  ...
# 1475  https://raidofinance.com/?utm_source=icowatchlist       Ethereum  ...
# 1476                         http://bluechipvision.com/       Ethereum  ...
# 1477                         http://bluechipvision.com/       Ethereum  ...
# 1478                             https://www.primary.io          Other  ...
# 1479                             https://www.primary.io          Other  ...
# 1480  https://weave.wearvr.com/?utm_source=icowatchl...        Stellar  ...
# 1481  https://weave.wearvr.com/?utm_source=icowatchl...        Stellar  ...
# 1482                                https://www.vanm.io       Ethereum  ...
# 1483                                https://www.vanm.io       Ethereum  ...
# 1484                                https://saltmine.io       Ethereum  ...
# 1485                                https://saltmine.io       Ethereum  ...
#
#                      Restricted Countries Total Raised    Total Tokens  \
# 0                           United States   $5,100,000             NaN
# 1                           United States   $5,100,000             NaN
# 2                           United States   $6,350,000             NaN
# 3                           United States   $6,350,000             NaN
# 4                           United States   $5,500,000             NaN
# 5                           United States   $5,500,000             NaN
# 6                           United States  $16,010,000             NaN
# 7                           United States  $16,010,000             NaN
# 8                           United States     $590,000             NaN
# 9                           United States     $590,000             NaN
# 10                          United States          NaN             NaN
# 11                          United States          NaN             NaN
# 12                          United States   $1,100,000             NaN
# 13                          United States   $1,100,000             NaN
# 14                          United States   $3,800,000             NaN
# 15                          United States   $3,800,000             NaN
# 16                          United States          NaN             NaN
# 17                          United States          NaN             NaN
# 18                          United States   $5,500,000             NaN
# 19                          United States   $5,500,000             NaN
# 20                          United States  $10,680,000             NaN
# 21                          United States  $10,680,000             NaN
# 22                          United States   $1,200,000             NaN
# 23                          United States   $1,200,000             NaN
# 24                          United States   $4,700,000             NaN
# 25                          United States   $4,700,000             NaN
# 26                          United States   $7,500,000             NaN
# 27                          United States   $7,500,000             NaN
# 28                          United States     $400,000             NaN
# 29                          United States     $400,000             NaN
# ...                                   ...          ...             ...
# 1456                        United States          NaN   1,000,000,000
# 1457                        United States          NaN   1,000,000,000
# 1458                        United States          NaN     350,000,000
# 1459                        United States          NaN     350,000,000
# 1460                        United States          NaN  10,000,000,000
# 1461                        United States          NaN  10,000,000,000
# 1462                        United States          NaN     100,000,000
# 1463                        United States          NaN     100,000,000
# 1464                        United States          NaN   2,000,000,000
# 1465                        United States          NaN   2,000,000,000
# 1466                 United States, China          NaN   1,000,000,000
# 1467                 United States, China          NaN   1,000,000,000
# 1468                        United States          NaN   1,000,000,000
# 1469                        United States          NaN   1,000,000,000
# 1470                        United States          NaN   1,000,000,000
# 1471                        United States          NaN   1,000,000,000
# 1472  United States, Syrian Arab Republic          NaN     200,000,000
# 1473  United States, Syrian Arab Republic          NaN     200,000,000
# 1474                        United States          NaN      86,250,000
# 1475                        United States          NaN      86,250,000
# 1476                        United States          NaN     473,392,856
# 1477                        United States          NaN     473,392,856
# 1478                        United States          NaN             NaN
# 1479                        United States          NaN             NaN
# 1480                        United States          NaN     960,000,000
# 1481                        United States          NaN     960,000,000
# 1482                        United States          NaN     240,000,000
# 1483                        United States          NaN     240,000,000
# 1484                        United States          NaN             NaN
# 1485                        United States          NaN             NaN
#
#      branches commits  forks           name stars  \
# 0         NaN     NaN    NaN          augur   NaN
# 1         644   84958  32284           lisk  1618
# 2         NaN     NaN    NaN       digixdao   NaN
# 3         280   41535   2773          waves  3611
# 4         NaN     NaN    NaN        stratis   NaN
# 5         711   29303  20191     taonetwork   655
# 6         NaN     NaN    NaN         incent   NaN
# 7         702   52579   2548            neo  2243
# 8         NaN     NaN    NaN       blockpay   NaN
# 9           0       0      0     firstblood     0
# 10        NaN     NaN    NaN        iconomi   NaN
# 11          0       0      0          lykke     0
# 12        NaN     NaN    NaN        synereo   NaN
# 13          0       0      0    singulardtv     0
# 14        NaN     NaN    NaN  beyondthevoid   NaN
# 15          0       0      0         decent     0
# 16        NaN     NaN    NaN          golem   NaN
# 17          0       0      0            ark     0
# 18        NaN     NaN    NaN        vdiceio   NaN
# 19         84    3559   1920         komodo   138
# 20        NaN     NaN    NaN          golos   NaN
# 21          0       0      0   creativecoin     0
# 22        NaN     NaN    NaN          wings   NaN
# 23       2828   77171   4810          tokes   249
# 24        NaN     NaN    NaN     chronobank   NaN
# 25         31    4457    103           qtum   138
# 26        NaN     NaN    NaN       edgeless   NaN
# 27          6     121     13          iexec    20
# 28        NaN     NaN    NaN    encryptotel   NaN
# 29          0       0      0         gnosis     0
# ...       ...     ...    ...            ...   ...
# 1456      NaN     NaN    NaN            NaN   NaN
# 1457        0       0      0            NaN     0
# 1458      NaN     NaN    NaN            NaN   NaN
# 1459        0       0      0            NaN     0
# 1460      NaN     NaN    NaN            NaN   NaN
# 1461        0       0      0            NaN     0
# 1462      NaN     NaN    NaN            NaN   NaN
# 1463       43     639     64            NaN    33
# 1464      NaN     NaN    NaN            NaN   NaN
# 1465        0       0      0            NaN     0
# 1466      NaN     NaN    NaN            NaN   NaN
# 1467      192    2751    112            NaN    33
# 1468      NaN     NaN    NaN            NaN   NaN
# 1469        0       0      0            NaN     0
# 1470      NaN     NaN    NaN            NaN   NaN
# 1471        0       0      0            NaN     0
# 1472      NaN     NaN    NaN            NaN   NaN
# 1473        5     160      0            NaN     1
# 1474      NaN     NaN    NaN            NaN   NaN
# 1475        0       0      0            NaN     0
# 1476      NaN     NaN    NaN            NaN   NaN
# 1477        0       0      0            NaN     0
# 1478      NaN     NaN    NaN            NaN   NaN
# 1479        0       0      0            NaN     0
# 1480      NaN     NaN    NaN            NaN   NaN
# 1481        0       0      0            NaN     0
# 1482      NaN     NaN    NaN            NaN   NaN
# 1483        0       0      0            NaN     0
# 1484      NaN     NaN    NaN            NaN   NaN
# 1485        0       0      0            NaN     0
#
#                                              url watchers
# 0             https://icowatchlist.com/ico/augur      NaN
# 1              https://icowatchlist.com/ico/lisk      587
# 2          https://icowatchlist.com/ico/digixdao      NaN
# 3             https://icowatchlist.com/ico/waves      641
# 4           https://icowatchlist.com/ico/stratis      NaN
# 5        https://icowatchlist.com/ico/taonetwork      323
# 6            https://icowatchlist.com/ico/incent      NaN
# 7               https://icowatchlist.com/ico/neo     1135
# 8          https://icowatchlist.com/ico/blockpay      NaN
# 9        https://icowatchlist.com/ico/firstblood        0
# 10          https://icowatchlist.com/ico/iconomi      NaN
# 11            https://icowatchlist.com/ico/lykke        0
# 12          https://icowatchlist.com/ico/synereo      NaN
# 13      https://icowatchlist.com/ico/singulardtv        0
# 14    https://icowatchlist.com/ico/beyondthevoid      NaN
# 15           https://icowatchlist.com/ico/decent        0
# 16            https://icowatchlist.com/ico/golem      NaN
# 17              https://icowatchlist.com/ico/ark        0
# 18          https://icowatchlist.com/ico/vdiceio      NaN
# 19           https://icowatchlist.com/ico/komodo       36
# 20            https://icowatchlist.com/ico/golos      NaN
# 21     https://icowatchlist.com/ico/creativecoin        0
# 22            https://icowatchlist.com/ico/wings      NaN
# 23            https://icowatchlist.com/ico/tokes     4903
# 24       https://icowatchlist.com/ico/chronobank      NaN
# 25             https://icowatchlist.com/ico/qtum      139
# 26         https://icowatchlist.com/ico/edgeless      NaN
# 27            https://icowatchlist.com/ico/iexec       25
# 28      https://icowatchlist.com/ico/encryptotel      NaN
# 29           https://icowatchlist.com/ico/gnosis        0
# ...                                          ...      ...
# 1456                                         NaN      NaN
# 1457                                         NaN        0
# 1458                                         NaN      NaN
# 1459                                         NaN        0
# 1460                                         NaN      NaN
# 1461                                         NaN        0
# 1462                                         NaN      NaN
# 1463                                         NaN       20
# 1464                                         NaN      NaN
# 1465                                         NaN        0
# 1466                                         NaN      NaN
# 1467                                         NaN       10
# 1468                                         NaN      NaN
# 1469                                         NaN        0
# 1470                                         NaN      NaN
# 1471                                         NaN        0
# 1472                                         NaN      NaN
# 1473                                         NaN        1
# 1474                                         NaN      NaN
# 1475                                         NaN        0
# 1476                                         NaN      NaN
# 1477                                         NaN        0
# 1478                                         NaN      NaN
# 1479                                         NaN        0
# 1480                                         NaN      NaN
# 1481                                         NaN        0
# 1482                                         NaN      NaN
# 1483                                         NaN        0
# 1484                                         NaN      NaN
# 1485                                         NaN        0
#
# [1486 rows x 23 columns]

# %%
#df.to_csv('token_with_github_feature.csv')

# %%
url = 'https://icowatchlist.com/ico/augur'

# %%
git_feature_list = []
for key, value in gitfeature.items():
    temp=(key, value)
    git_feature_list.append(temp)

# %%
git_feature_list
# Out:
# [('watchers', 590),
#  ('stars', 1630),
#  ('forks', 32289),
#  ('commits', 85017),
#  ('branches', 644)]

# %%
results = []
html = requests.get(url)
htmltxt = bs(html.text, 'html.parser')
htmlbody = htmltxt.body
heads = htmlbody.find_all("div", class_="col-xs-6 col-md-3")[2:]
heads = [head.text.strip().split('\n')[0] for head in heads]
datas = htmlbody.find_all("div", class_="col-xs-6 col-md-9")[2:]
datas = [data.text.strip().split('\n')[0] for data in datas]
ico_results = list(zip(heads, datas))


github_link = get_github_link(htmlbody)
website_link = get_webpage_link(htmlbody)
ico_results.append(('Github URL', github_link))
ico_results.append(('Official Website', website_link))
results.append(ico_results)

git_feature = gitfeature_html(github_link)
git_feature_list = []
for key, value in git_feature.items():
    temp=(key, value)
    git_feature_list.append(temp)

joinedlist = ico_results + git_feature_list
results.append(joinedlist)

# %%
results
# Out:
# [[('Platform', 'Ethereum'),
#   ('Country', 'Unknown'),
#   ('Restricted Countries', 'United States'),
#   ('Initial Token Price', '$0.5800'),
#   ('Funds in Escrow?', 'No'),
#   ('Coin Symbol', 'REP'),
#   ('Price Now', '$15.43'),
#   ('Total Raised', '$5,100,000'),
#   ('ROI', '2,560.43%'),
#   ('Github URL', 'https://github.com/AugurProject'),
#   ('Official Website', 'https://www.augur.net/')],
#  [('Platform', 'Ethereum'),
#   ('Country', 'Unknown'),
#   ('Restricted Countries', 'United States'),
#   ('Initial Token Price', '$0.5800'),
#   ('Funds in Escrow?', 'No'),
#   ('Coin Symbol', 'REP'),
#   ('Price Now', '$15.43'),
#   ('Total Raised', '$5,100,000'),
#   ('ROI', '2,560.43%'),
#   ('Github URL', 'https://github.com/AugurProject'),
#   ('Official Website', 'https://www.augur.net/'),
#   ('watchers', 590),
#   ('stars', 1630),
#   ('forks', 32289),
#   ('commits', 85017),
#   ('branches', 644)]]

# %%
joinedlist
# Out:
# [('Platform', 'Ethereum'),
#  ('Country', 'Unknown'),
#  ('Restricted Countries', 'United States'),
#  ('Initial Token Price', '$0.5800'),
#  ('Funds in Escrow?', 'No'),
#  ('Coin Symbol', 'REP'),
#  ('Price Now', '$15.43'),
#  ('Total Raised', '$5,100,000'),
#  ('ROI', '2,560.43%'),
#  ('Github URL', 'https://github.com/AugurProject'),
#  ('Official Website', 'https://www.augur.net/'),
#  ('watchers', 590),
#  ('stars', 1630),
#  ('forks', 32289),
#  ('commits', 85017),
#  ('branches', 644)]

# %%
len(joinedlist)
# Out:
# 16

# %%
len(ico_results)
# Out:
# 11

# %%
len(git_feature_list)
# Out:
# 5

# %%
|
